# %%
import pandas as pd

# %%
df=pd.read_csv("users/baoqiangzhang/Downloads/sales_data.csv")

# %%
df #To see what is in the data
# Out:
#          Product    Region   Price  Units Sold   Sale Date
# 0            NaN  Region_1   72.87        10.0  2022-01-01
# 1     Product_40  Region_2   46.19        10.0  2022-01-02
# 2      Product_1  Region_5     NaN         4.0  2022-01-03
# 3      Product_6  Region_8  143.47         8.0  2022-01-04
# 4     Product_44  Region_4  122.54        10.0  2022-01-05
# ...          ...       ...     ...         ...         ...
# 1045  Product_42  Region_3   18.63         9.0  2023-07-10
# 1046   Product_4  Region_3  159.27        10.0  2024-07-14
# 1047  Product_43  Region_1    2.91        13.0  2023-08-17
# 1048  Product_27  Region_7    1.96         8.0  2024-03-10
# 1049   Product_3       NaN  302.68        11.0  2023-09-09
#
# [1050 rows x 5 columns]

# %%
df['Product'].describe() # Look in to products
# Out:
# count           947
# unique           50
# top       Product_4
# freq             30
# Name: Product, dtype: object

# %%
#There are 50 product and product4 sold most

# %%
df['Price'].describe() #look into the price
# Out:
# count     945.000000
# mean      108.628011
# std       167.350086
# min         0.190000
# 25%        26.420000
# 50%        64.640000
# 75%       142.310000
# max      2636.900000
# Name: Price, dtype: float64

# %%
df.groupby('Region')['Product'].describe() #look into Region and Product
# Out:
#           count unique         top freq
# Region
# Region_1     80     41  Product_43    4
# Region_10    84     41   Product_4    5
# Region_2     88     40  Product_49    6
# Region_3     81     39   Product_4    6
# Region_4     79     40  Product_45    6
# Region_5    100     45   Product_8    5
# Region_6     77     38  Product_20    5
# Region_7     87     39   Product_3    5
# Region_8     85     37  Product_10    5
# Region_9     90     43  Product_50    5

# %%
# 10 different Regions appeared around 90 times each

# %%
df.groupby('Product')['Price'].describe() #look into the different product with the different price
# Out:
#             count        mean         std    min      25%      50%       75%  \
# Product
# Product_1    19.0   99.960526  108.592682   3.40  46.8550   75.880  107.4200
# Product_10   17.0   97.610588   77.320574   3.63  36.2400   85.330  121.6500
# Product_11   12.0  120.550833   98.670114  21.70  61.6225   78.720  142.3325
# Product_12   14.0   77.138571   65.900566   2.37  30.6700   62.570  108.5425
# Product_13   17.0   88.629412   85.923571  12.86  18.2100   54.910  145.8400
# Product_14   10.0   95.544000  140.334625   4.15  17.6350   40.905  102.9875
# Product_15   19.0   89.121053  102.348294   5.71  24.2300   39.720  140.4600
# Product_16   13.0   77.116154  104.202676   4.52  11.2800   46.950   91.9800
# Product_17   21.0  127.157143   88.934104   5.39  54.6500  120.080  180.6100
# Product_18   11.0  107.107273  117.847272   1.90  18.7450   97.780  139.1000
# Product_19   20.0  115.748500   82.634176  16.82  46.6175   96.925  158.4750
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['Price']) #look the genral price
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
df[df['Price']>500] #look the extreme price value
# Out:
#          Product     Region    Price  Units Sold   Sale Date
# 85    Product_44   Region_2   521.88         NaN  2022-03-27
# 269   Product_49   Region_8  1296.00        14.0  2022-09-27
# 407   Product_27   Region_7  1793.90         9.0  2023-02-12
# 421   Product_34   Region_2  2636.90        14.0  2023-02-26
# 435   Product_50   Region_9   531.91         7.0  2023-03-12
# 737    Product_7  Region_10   501.57        17.0  2024-01-08
# 745   Product_50  Region_10   650.50         6.0  2024-01-16
# 839          NaN   Region_7   606.29         9.0  2024-04-19
# 855   Product_40        NaN   570.60        14.0  2024-05-05
# 1026         NaN   Region_5  2544.60        15.0  2023-02-22

# %%
df1=df[df['Price']<600] #exclude extreme price

# %%
df1
# Out:
#          Product    Region   Price  Units Sold   Sale Date
# 0            NaN  Region_1   72.87        10.0  2022-01-01
# 1     Product_40  Region_2   46.19        10.0  2022-01-02
# 3      Product_6  Region_8  143.47         8.0  2022-01-04
# 4     Product_44  Region_4  122.54        10.0  2022-01-05
# 5     Product_21  Region_8   15.76        20.0  2022-01-06
# ...          ...       ...     ...         ...         ...
# 1045  Product_42  Region_3   18.63         9.0  2023-07-10
# 1046   Product_4  Region_3  159.27        10.0  2024-07-14
# 1047  Product_43  Region_1    2.91        13.0  2023-08-17
# 1048  Product_27  Region_7    1.96         8.0  2024-03-10
# 1049   Product_3       NaN  302.68        11.0  2023-09-09
#
# [939 rows x 5 columns]

# %%
sns.histplot(df1['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(df1.reset_index()['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
df1.groupby('Product')['Region'].describe()
# Out:
#            count unique        top freq
# Product
# Product_1     17      9   Region_7    3
# Product_10    16     10   Region_8    4
# Product_11    11      7  Region_10    3
# Product_12    13      6   Region_6    3
# Product_13    17      7   Region_9    3
# Product_14     9      6   Region_1    3
# Product_15    19      9   Region_8    4
# Product_16    12      8   Region_5    3
# Product_17    17      9   Region_7    3
# Product_18     9      6   Region_2    2
# Product_19    16      8  Region_10    3
# Product_2     13      8   Region_6    3
# Product_20    15      7   Region_6    5
# Product_21    13      8   Region_9    3
# Product_22    15      8   Region_4    3
# Product_23    17      8   Region_8    3
# Product_24    23     10   Region_9    4
# Product_25    12      7   Region_5    4
# Product_26    15      8   Region_3    3
# Product_27    20      9   Region_8    4
# Product_28    14      8   Region_8    3
# Product_29    12      8  Region_10    3
# ...

# %%
df1.groupby('Product')['Price'].describe()
# Out:
#             count        mean         std    min      25%      50%       75%  \
# Product
# Product_1    19.0   99.960526  108.592682   3.40  46.8550   75.880  107.4200
# Product_10   17.0   97.610588   77.320574   3.63  36.2400   85.330  121.6500
# Product_11   12.0  120.550833   98.670114  21.70  61.6225   78.720  142.3325
# Product_12   14.0   77.138571   65.900566   2.37  30.6700   62.570  108.5425
# Product_13   17.0   88.629412   85.923571  12.86  18.2100   54.910  145.8400
# Product_14   10.0   95.544000  140.334625   4.15  17.6350   40.905  102.9875
# Product_15   19.0   89.121053  102.348294   5.71  24.2300   39.720  140.4600
# Product_16   13.0   77.116154  104.202676   4.52  11.2800   46.950   91.9800
# Product_17   21.0  127.157143   88.934104   5.39  54.6500  120.080  180.6100
# Product_18   11.0  107.107273  117.847272   1.90  18.7450   97.780  139.1000
# Product_19   20.0  115.748500   82.634176  16.82  46.6175   96.925  158.4750
# ...

# %%
sns.boxplot(data=df1.reset_index(),x='Region',y='Price')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Price'>

# %%
#Consumption level is fairly equal

# %%
missing=df.isnull().sum() #Clean the data, first check the missing value in the dataset.
print(missing)
# Out:
# Product       90
# Region        98
# Price          0
# Units Sold    99
# Sale Date      0
# dtype: int64

# %%
df1 = df1.drop_

# %%
sns.histplot(df1.reset_index()['Product'])
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Count'>
